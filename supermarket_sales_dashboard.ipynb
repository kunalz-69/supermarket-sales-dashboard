# %%
# 📦 Import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 📥 Load Dataset
df = pd.read_csv("supermarket_sales_for_kunal.csv")

# 🧹 Data Overview
print("Dataset Shape:", df.shape)
df.info()
print("\nMissing values:\n", df.isnull().sum())
display(df.describe())
display(df.head())

# 🧠 Convert Date column to datetime
df['Date'] = pd.to_datetime(df['Date'])

# 📊 1. Sales by Gender
plt.figure(figsize=(6,4))
sns.countplot(x='Gender', data=df, palette='Set2')
plt.title("Sales Count by Gender")
plt.xlabel("Gender")
plt.ylabel("Number of Sales")
plt.show()

# 📊 2. Payment Method Usage
plt.figure(figsize=(6,4))
sns.countplot(x='Payment', data=df, palette='pastel')
plt.title("Payment Method Usage")
plt.xlabel("Payment Method")
plt.ylabel("Frequency")
plt.show()

# 📊 3. Average Rating per Product Line
plt.figure(figsize=(10,6))
sns.barplot(x='Product line', y='Rating', data=df, palette='viridis')
plt.title("Average Rating by Product Line")
plt.xticks(rotation=45)
plt.ylabel("Average Rating")
plt.show()

# 📊 4. Total Sales by Branch
plt.figure(figsize=(6,4))
sns.barplot(x='Branch', y='Total', data=df, estimator=sum, palette='cool')
plt.title("Total Sales by Branch")
plt.ylabel("Total Revenue")
plt.show()

# 📈 5. Daily Sales Trend
daily_sales = df.groupby('Date').sum(numeric_only=True)['Total']
plt.figure(figsize=(12,5))
daily_sales.plot(marker='o')
plt.title("Daily Sales Trend")
plt.xlabel("Date")
plt.ylabel("Total Sales")
plt.grid()
plt.show()
# Out:
# Dataset Shape: (2, 17)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               2 non-null      object
#  1   Branch                   2 non-null      object
#  2   City                     2 non-null      object
#  3   Customer type            2 non-null      object
#  4   Gender                   2 non-null      object
#  5   Product line             2 non-null      object
#  6   Unit price               2 non-null      float64
#  7   Quantity                 2 non-null      int64
#  8   Tax 5%                   2 non-null      float64
#  9   Total                    2 non-null      float64
#  10  Date                     2 non-null      object
#  11  Time                     2 non-null      object
#  12  Payment                  2 non-null      object
# ...
